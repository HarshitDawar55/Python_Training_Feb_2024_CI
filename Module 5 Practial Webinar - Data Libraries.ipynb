# %% [markdown]
# # Data Libraries Practical by `Mr. Harshit Dawar!`

# %%
import pandas as pd
import numpy as np

# %%
red_wine_df = pd.read_csv("winequality-red - winequality-red.csv.csv")
white_wine_df = pd.read_csv("winequality-white - winequality-white.csv.csv")

# %%
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red_wine_df.shape
# Out:
# (1599, 13)

# %%
white_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
white_wine_df["quality"].unique()
# Out:
# array([6, 5, 7, 8, 4, 3, 9], dtype=int64)

# %%
red_wine_df["quality"].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
red_wine_df["Unnamed"].unique()
# Out:
# array([0], dtype=int64)

# %%
white_wine_df.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
# 5            8.1              0.28         0.40             6.9      0.050
# 6            6.2              0.32         0.16             7.0      0.045
# 7            7.0              0.27         0.36            20.7      0.045
# 8            6.3              0.30         0.34             1.6      0.049
# 9            8.1              0.22         0.43             1.5      0.044
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
white_wine_df.tail(10)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4888            6.8             0.220         0.36            1.20      0.052
# 4889            4.9             0.235         0.27           11.75      0.030
# 4890            6.1             0.340         0.29            2.20      0.036
# 4891            5.7             0.210         0.32            0.90      0.038
# 4892            6.5             0.230         0.38            1.30      0.032
# 4893            6.2             0.210         0.29            1.60      0.039
# 4894            6.6             0.320         0.36            8.00      0.047
# 4895            6.5             0.240         0.19            1.20      0.041
# 4896            5.5             0.290         0.30            1.10      0.022
# 4897            6.0             0.210         0.38            0.80      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
white_wine_df.iloc[100 : 1001]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 100             7.4             0.250         0.37           13.50      0.060
# 101             7.1             0.120         0.32            9.60      0.054
# 102             6.0             0.210         0.24           12.10      0.050
# 103             7.5             0.305         0.40           18.90      0.059
# 104             7.4             0.250         0.37           13.50      0.060
# ...             ...               ...          ...             ...        ...
# 996             6.0             0.260         0.34            1.30      0.046
# 997             6.1             0.240         0.27            9.80      0.062
# 998             8.0             0.240         0.30           17.45      0.056
# 999             7.6             0.210         0.60            2.10      0.046
# 1000            8.0             0.190         0.36            1.80      0.050
#
# ...

# %% [markdown]
# ### Task 2 - Exploring the differnet/basic properties of the data

# %%
print(f"Shape of White Wine Dataframe is {white_wine_df.shape}")
print(f"Shape of Red Wine Dataframe is {red_wine_df.shape}")
# Out:
# Shape of White Wine Dataframe is (4898, 12)
# Shape of Red Wine Dataframe is (1599, 13)

# %%
print(f"Columns present in White Wine Dataframe are {white_wine_df.columns}")
print(f"Columns present in Red Wine Dataframe are {red_wine_df.columns}")
# Out:
# Columns present in White Wine Dataframe are Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
# Columns present in Red Wine Dataframe are Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Unnamed'],
#       dtype='object')

# %%
white_wine_df["fixed acidity"]
# Out:
# 0       7.0
# 1       6.3
# 2       8.1
# 3       7.2
# 4       7.2
#        ...
# 4893    6.2
# 4894    6.6
# 4895    6.5
# 4896    5.5
# 4897    6.0
# Name: fixed acidity, Length: 4898, dtype: float64

# %%
print(red_wine_df.dtypes)
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# Unnamed                   int64
# dtype: object

# %%
white_wine_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
red_wine_df.dtypes
red_wine_df.columns
white_wine_df.columns
white_wine_df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
red_wine_df.index
# Out:
# RangeIndex(start=0, stop=1599, step=1)

# %%
list(range(1, 10, 2))
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# ### Task 3 - Combining 2 dataframes and working on them

# %%
red_wine_df["wine_type"] = "red"
white_wine_df["wine_type"] = "white"

# %%
red_wine_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
final_df = pd.concat([red_wine_df, white_wine_df], axis = 0).reset_index(drop=True)
final_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
red_wine_df.shape[0] + white_wine_df.shape[0]
# Out:
# 6497

# %%
final_df = final_df.drop("Unnamed", axis = 1)
final_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  wine_type             6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
final_df.isna().sum().sum()
# Out:
# 0

# %%
final_df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
final_df[final_df["citric acid"] > 1]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2344            7.4              0.20         1.66             2.1      0.022
# 4751            7.6              0.25         1.23             4.6      0.035
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2344                 34.0                 113.0  0.99165  3.26       0.55
# 4751                 51.0                 294.0  0.99018  3.03       0.43
#
#       alcohol  quality wine_type
# 2344     12.2        6     white
# 4751     13.1        6     white

# %%
final_df["citric acid"].plot(kind = "hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
final_df[final_df.duplicated() == True]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 6427            6.4             0.230         0.35           10.30      0.042
# 6449            7.0             0.360         0.35            2.50      0.048
# 6450            6.4             0.330         0.44            8.90      0.055
# 6455            7.1             0.230         0.39           13.70      0.058
# 6479            6.6             0.340         0.40            8.10      0.046
#
# ...

# %%
final_df.duplicated().sum()
# Out:
# 1177

# %%
final_df.drop_duplicates(inplace=True)

# %%
final_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ### Task 4 - Creating new features by combining existing ones

# %%
final_df["sulphur_dioxides"] = final_df["free sulfur dioxide"] + final_df["total sulfur dioxide"]

# %%
final_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
final_df["acids"] = final_df["fixed acidity"] + final_df["volatile acidity"] + final_df["citric acid"]

# %%
final_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 5               7.4              0.66         0.00             1.8      0.075
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
final_df = final_df.drop(["free sulfur dioxide", "total sulfur dioxide", "fixed acidity", "volatile acidity", "citric acid"], axis = 1)
final_df
# Out:
#       residual sugar  chlorides  density    pH  sulphates  alcohol  quality  \
# 0                1.9      0.076  0.99780  3.51       0.56      9.4        5
# 1                2.6      0.098  0.99680  3.20       0.68      9.8        5
# 2                2.3      0.092  0.99700  3.26       0.65      9.8        5
# 3                1.9      0.075  0.99800  3.16       0.58      9.8        6
# 5                1.8      0.075  0.99780  3.51       0.56      9.4        5
# ...              ...        ...      ...   ...        ...      ...      ...
# 6492             1.6      0.039  0.99114  3.27       0.50     11.2        6
# 6493             8.0      0.047  0.99490  3.15       0.46      9.6        5
# 6494             1.2      0.041  0.99254  2.99       0.46      9.4        6
# 6495             1.1      0.022  0.98869  3.34       0.38     12.8        7
# 6496             0.8      0.020  0.98941  3.26       0.32     11.8        6
#
#      wine_type  sulphur_dioxides  acids
# ...

# %% [markdown]
# ### Task 5 - Grouping and analyzing

# %%
grouped_df = final_df.groupby("wine_type")

# %%
grouped_df["quality"].mean()
# Out:
# wine_type
# red      5.623252
# white    5.854835
# Name: quality, dtype: float64

# %%
grouped_df.get_group("red").mean()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_30680\1343040446.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   grouped_df.get_group("red").mean()
# residual sugar       2.523400
# chlorides            0.088124
# density              0.996709
# pH                   3.309787
# sulphates            0.658705
# alcohol             10.432315
# quality              5.623252
# sulphur_dioxides    62.719279
# acids                9.112406
# dtype: float64

# %%
grouped_df.get_group("white").mean()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_30680\2708135885.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   grouped_df.get_group("white").mean()
# residual sugar        5.914819
# chlorides             0.045905
# density               0.993790
# pH                    3.195458
# sulphates             0.490351
# alcohol              10.589358
# quality               5.854835
# sulphur_dioxides    172.082681
# acids                 7.454216
# dtype: float64

# %%
final_df.corr()
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_30680\2626907977.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   final_df.corr()
#                   residual sugar  chlorides   density        pH  sulphates  \
# residual sugar          1.000000  -0.123094  0.520930 -0.234522  -0.174717
# chlorides              -0.123094   1.000000  0.371867  0.025823   0.405051
# density                 0.520930   0.371867  1.000000  0.034273   0.282690
# pH                     -0.234522   0.025823  0.034273  1.000000   0.168150
# sulphates              -0.174717   0.405051  0.282690  0.168150   1.000000
# alcohol                -0.305242  -0.269601 -0.667811  0.097314  -0.017232
# quality                -0.056830  -0.202137 -0.326434  0.039733   0.041884
# ...
